# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
import zipfile
import time
import os
import cv2
import numpy as np
import json
import tensorflow as tf
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten, concatenate, LSTM, Lambda, TimeDistributed
from keras.models import Model, load_model, model_from_json
from keras.backend import expand_dims
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, CSVLogger
from VideoDataGenerator import VideoDataGenerator
import tensorflow as tf
from keras.layers import Reshape, Dense, Input, Conv2D, MaxPooling2D, Flatten, concatenate, LSTM, Lambda, TimeDistributed, Dropout, BatchNormalization
from keras.models import Model
from keras.backend import expand_dims
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def loadMetadata(file):
    jsonFile =  open(file)
    data = json.load(jsonFile)

    labels = {}
    testIDs = []
    validIDs = []
    # every fifth key is validID, the rest are testID
    
    for validID in data['valid'].keys():
        validIDs.append(validID)
        labels[validID] = {
          'label': data['valid'][validID]['label'],
          'audioPrediction': data['valid'][validID]['fakeAudioPrediction']
        }
        
    for testID in data['test'].keys():
        testIDs.append(testID)
        labels[testID] = {
          'label': data['test'][testID]['label'],
          'audioPrediction': data['test'][testID]['fakeAudioPrediction']
        }
        
    return (testIDs, validIDs, labels, len(testIDs), len(validIDs))

# %%
#    -- Image PreProcessing Model --

# Our input feature map is 150x150x3: 150x150 for the image pixels, and 3 for
# the three color channels: R, G, and B
vid_input = Input(shape=(90, 150, 150, 3))

# First convolution extracts 4 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
# Increase first set of filters from v2
model = TimeDistributed(Conv2D(5, (4,4), activation='relu'))(vid_input)
model = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(model)
model = TimeDistributed(BatchNormalization())(model)

# Second convolution extracts 5 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window

model = TimeDistributed(Conv2D(6, (4,4), activation='relu'))(model)
model = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(model)
model = TimeDistributed(BatchNormalization())(model)

# Third convolution extracts 10 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window

model = TimeDistributed(Conv2D(10, (3,3), activation='relu'))(model)
model = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(model)
model = TimeDistributed(BatchNormalization())(model)


model = TimeDistributed(Flatten())(model)

#    -- Audio PreProcessing Model --
aud_input = Input(shape=(1,))

# Put through a layer with linear activation
aud_model = Dense(90, activation='linear')(aud_input)
aud_model = Reshape((90,1))(aud_model)

#     -- Concatenate Layers --
model = concatenate([model, aud_model])

model = TimeDistributed(Dense(512, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)
model = TimeDistributed(Dense(256, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)
model = TimeDistributed(Dense(127, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)

model = LSTM(1)(model)

output = Dense(1, activation='sigmoid')(model)

model = Model(inputs=[vid_input, aud_input], outputs=output)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 90, 150, 150, 0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 90, 148, 148, 168         input_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 90, 74, 74, 6 0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 90, 74, 74, 6 24          time_distributed_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 90, 72, 72, 7 385         time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 90, 36, 36, 7 0           time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 90, 36, 36, 7 28          time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 90, 34, 34, 1 640         time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 90, 17, 17, 1 0           time_distributed_7[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 90, 17, 17, 1 40          time_distributed_8[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 90)           180         input_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 90, 2890)     0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 90, 1)        0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 90, 2891)     0           time_distributed_10[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 90, 512)      1480704     concatenate_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 90, 512)      2048        time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 90, 512)      0           time_distributed_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 90, 256)      131328      time_distributed_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 90, 256)      1024        time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 90, 256)      0           time_distributed_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 90, 127)      32639       time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 90, 127)      508         time_distributed_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 90, 127)      0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 1)            516         time_distributed_19[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            2           lstm_1[0][0]
# ==================================================================================================
# Total params: 1,650,234
# Trainable params: 1,648,398
# Non-trainable params: 1,836
# __________________________________________________________________________________________________
# None

# %%
modelDirectory = '/home/jbschmid/models/v5'
dataDirectory = '/home/jbschmid/merged_data'

modelPath = os.path.join(modelDirectory, 'model.h5')
loadWeightsPath = os.path.join(modelDirectory, 'weights.h5')
saveWeightsPath = os.path.join(modelDirectory, 'weights.h5')
historyPath = os.path.join(modelDirectory, 'history.csv')
metadataPath =  './processed-metadata.json'

# load model
#model.save(modelPath)

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr = 0.001),
              metrics = ['acc'])

# Load previous training weights
#model.load_weights(loadWeightsPath)
checkpoint = ModelCheckpoint(filepath=saveWeightsPath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

csvLogger = CSVLogger(historyPath, append=True, separator=',')

(testIDs, validIDs, labels, numTestIDs, numValidIDs) = loadMetadata(metadataPath)

epochs = 100
batchSize = 20
testStepsPerEpoch = int(numTestIDs / batchSize)
validStepsPerEpoch = int(numValidIDs / batchSize)

testGen = VideoDataGenerator(testIDs, labels, dataDirectory, 
                             batchSize=batchSize, videoDim=(150,150,3))
validGen = VideoDataGenerator(validIDs, labels, dataDirectory, 
                              batchSize=batchSize, videoDim=(150,150,3))


# Train model
history = model.fit_generator(
      generator=testGen,
      steps_per_epoch=testStepsPerEpoch,  
      epochs=epochs,
      validation_data=validGen,
      validation_steps=validStepsPerEpoch,
      workers=8,
      callbacks=[checkpoint, csvLogger]
      )
# Out:
# Epoch 1/100
# 389/389 [==============================] - 629s 2s/step - loss: 0.6530 - acc: 0.5783 - val_loss: 0.6291 - val_acc: 0.5892
#
# Epoch 00001: val_acc improved from -inf to 0.58918, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 2/100
# 389/389 [==============================] - 617s 2s/step - loss: 0.6257 - acc: 0.6060 - val_loss: 0.6295 - val_acc: 0.5845
#
# Epoch 00002: val_acc did not improve from 0.58918
# Epoch 3/100
# 389/389 [==============================] - 619s 2s/step - loss: 0.6021 - acc: 0.6753 - val_loss: 0.7064 - val_acc: 0.6139
#
# Epoch 00003: val_acc improved from 0.58918 to 0.61392, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 4/100
# 389/389 [==============================] - 620s 2s/step - loss: 0.5824 - acc: 0.6999 - val_loss: 0.6168 - val_acc: 0.6268
#
# Epoch 00004: val_acc improved from 0.61392 to 0.62680, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 5/100
# 389/389 [==============================] - 614s 2s/step - loss: 0.5613 - acc: 0.7207 - val_loss: 0.6694 - val_acc: 0.6588
#
# Epoch 00005: val_acc improved from 0.62680 to 0.65876, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 6/100
# 389/389 [==============================] - 612s 2s/step - loss: 0.5498 - acc: 0.7346 - val_loss: 0.5533 - val_acc: 0.7371
#
# Epoch 00006: val_acc improved from 0.65876 to 0.73711, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 7/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.5200 - acc: 0.7473 - val_loss: 0.5818 - val_acc: 0.6474
#
# Epoch 00007: val_acc did not improve from 0.73711
# Epoch 8/100
# 389/389 [==============================] - 610s 2s/step - loss: 0.5041 - acc: 0.7393 - val_loss: 0.5257 - val_acc: 0.7134
#
# Epoch 00008: val_acc did not improve from 0.73711
# Epoch 9/100
# 389/389 [==============================] - 608s 2s/step - loss: 0.4850 - acc: 0.7541 - val_loss: 0.5465 - val_acc: 0.7026
#
# Epoch 00009: val_acc did not improve from 0.73711
# Epoch 10/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.4553 - acc: 0.7721 - val_loss: 0.5980 - val_acc: 0.7139
#
# Epoch 00010: val_acc did not improve from 0.73711
# Epoch 11/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.4414 - acc: 0.7861 - val_loss: 0.4888 - val_acc: 0.7557
#
# Epoch 00011: val_acc improved from 0.73711 to 0.75567, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 12/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.4214 - acc: 0.8059 - val_loss: 0.4729 - val_acc: 0.7644
#
# Epoch 00012: val_acc improved from 0.75567 to 0.76443, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 13/100
# 389/389 [==============================] - 608s 2s/step - loss: 0.3954 - acc: 0.8267 - val_loss: 0.4815 - val_acc: 0.7825
#
# Epoch 00013: val_acc improved from 0.76443 to 0.78247, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 14/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.3837 - acc: 0.8306 - val_loss: 0.4817 - val_acc: 0.7840
#
# Epoch 00014: val_acc improved from 0.78247 to 0.78402, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 15/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.3748 - acc: 0.8411 - val_loss: 0.4929 - val_acc: 0.7809
#
# Epoch 00015: val_acc did not improve from 0.78402
# Epoch 16/100
# 389/389 [==============================] - 611s 2s/step - loss: 0.3637 - acc: 0.8467 - val_loss: 0.5235 - val_acc: 0.7541
#
# Epoch 00016: val_acc did not improve from 0.78402
# Epoch 17/100
# 389/389 [==============================] - 610s 2s/step - loss: 0.3404 - acc: 0.8607 - val_loss: 0.5008 - val_acc: 0.7820
#
# Epoch 00017: val_acc did not improve from 0.78402
# Epoch 18/100
# 389/389 [==============================] - 609s 2s/step - loss: 0.3227 - acc: 0.8701 - val_loss: 0.4877 - val_acc: 0.7871
#
# Epoch 00018: val_acc improved from 0.78402 to 0.78711, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 19/100
# 389/389 [==============================] - 609s 2s/step - loss: 0.3225 - acc: 0.8703 - val_loss: 0.4937 - val_acc: 0.7933
#
# Epoch 00019: val_acc improved from 0.78711 to 0.79330, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 20/100
# 389/389 [==============================] - 609s 2s/step - loss: 0.3058 - acc: 0.8787 - val_loss: 0.5621 - val_acc: 0.7665
#
# Epoch 00020: val_acc did not improve from 0.79330
# Epoch 21/100
# 389/389 [==============================] - 597s 2s/step - loss: 0.3066 - acc: 0.8784 - val_loss: 0.5033 - val_acc: 0.7964
#
# Epoch 00021: val_acc improved from 0.79330 to 0.79639, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 22/100
# 389/389 [==============================] - 603s 2s/step - loss: 0.2851 - acc: 0.8914 - val_loss: 0.5351 - val_acc: 0.7881
#
# Epoch 00022: val_acc did not improve from 0.79639
# Epoch 23/100
# 389/389 [==============================] - 598s 2s/step - loss: 0.2780 - acc: 0.8932 - val_loss: 0.5880 - val_acc: 0.7732
#
# Epoch 00023: val_acc did not improve from 0.79639
# Epoch 24/100
# 389/389 [==============================] - 602s 2s/step - loss: 0.2713 - acc: 0.8981 - val_loss: 0.5011 - val_acc: 0.7881
#
# Epoch 00024: val_acc did not improve from 0.79639
# Epoch 25/100
# 389/389 [==============================] - 599s 2s/step - loss: 0.2656 - acc: 0.8991 - val_loss: 0.6067 - val_acc: 0.7696
#
# Epoch 00025: val_acc did not improve from 0.79639
# Epoch 26/100
# 389/389 [==============================] - 598s 2s/step - loss: 0.2464 - acc: 0.9075 - val_loss: 0.5019 - val_acc: 0.8031
#
# Epoch 00026: val_acc improved from 0.79639 to 0.80309, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 27/100
# 389/389 [==============================] - 602s 2s/step - loss: 0.2459 - acc: 0.9082 - val_loss: 0.5674 - val_acc: 0.7912
#
# Epoch 00027: val_acc did not improve from 0.80309
# Epoch 28/100
# 389/389 [==============================] - 602s 2s/step - loss: 0.2457 - acc: 0.9117 - val_loss: 0.5230 - val_acc: 0.7923
#
# Epoch 00028: val_acc did not improve from 0.80309
# Epoch 29/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.2249 - acc: 0.9180 - val_loss: 0.5624 - val_acc: 0.7835
#
# Epoch 00029: val_acc did not improve from 0.80309
# Epoch 30/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.2260 - acc: 0.9165 - val_loss: 0.5669 - val_acc: 0.7851
#
# Epoch 00030: val_acc did not improve from 0.80309
# Epoch 31/100
# 389/389 [==============================] - 605s 2s/step - loss: 0.2165 - acc: 0.9225 - val_loss: 0.6447 - val_acc: 0.7773
#
# Epoch 00031: val_acc did not improve from 0.80309
# Epoch 32/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.2136 - acc: 0.9220 - val_loss: 0.5633 - val_acc: 0.7912
#
# Epoch 00032: val_acc did not improve from 0.80309
# Epoch 33/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.1996 - acc: 0.9314 - val_loss: 0.5421 - val_acc: 0.7969
#
# Epoch 00033: val_acc did not improve from 0.80309
# Epoch 34/100
# 389/389 [==============================] - 603s 2s/step - loss: 0.1923 - acc: 0.9326 - val_loss: 0.5560 - val_acc: 0.8129
#
# Epoch 00034: val_acc improved from 0.80309 to 0.81289, saving model to /home/jbschmid/models/v5/weights.h5
# Epoch 35/100
# 389/389 [==============================] - 603s 2s/step - loss: 0.1913 - acc: 0.9343 - val_loss: 0.7594 - val_acc: 0.7376
#
# Epoch 00035: val_acc did not improve from 0.81289
# Epoch 36/100
# 389/389 [==============================] - 603s 2s/step - loss: 0.1797 - acc: 0.9373 - val_loss: 0.5685 - val_acc: 0.7928
#
# Epoch 00036: val_acc did not improve from 0.81289
# Epoch 37/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.1790 - acc: 0.9379 - val_loss: 0.6101 - val_acc: 0.7881
#
# Epoch 00037: val_acc did not improve from 0.81289
# Epoch 38/100
# 389/389 [==============================] - 606s 2s/step - loss: 0.1702 - acc: 0.9398 - val_loss: 0.6067 - val_acc: 0.7979
#
# Epoch 00038: val_acc did not improve from 0.81289
# Epoch 39/100
# 389/389 [==============================] - 606s 2s/step - loss: 0.1646 - acc: 0.9434 - val_loss: 0.6304 - val_acc: 0.7861
#
# Epoch 00039: val_acc did not improve from 0.81289
# Epoch 40/100
# 389/389 [==============================] - 603s 2s/step - loss: 0.1701 - acc: 0.9415 - val_loss: 0.6790 - val_acc: 0.7758
#
# Epoch 00040: val_acc did not improve from 0.81289
# Epoch 41/100
# 389/389 [==============================] - 603s 2s/step - loss: 0.1555 - acc: 0.9472 - val_loss: 0.6141 - val_acc: 0.8010
#
# Epoch 00041: val_acc did not improve from 0.81289
# Epoch 42/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.1571 - acc: 0.9467 - val_loss: 0.6041 - val_acc: 0.8108
#
# Epoch 00042: val_acc did not improve from 0.81289
# Epoch 43/100
# 389/389 [==============================] - 605s 2s/step - loss: 0.1392 - acc: 0.9553 - val_loss: 0.6441 - val_acc: 0.7840
#
# Epoch 00043: val_acc did not improve from 0.81289
# Epoch 44/100
# 389/389 [==============================] - 604s 2s/step - loss: 0.1419 - acc: 0.9527 - val_loss: 0.6528 - val_acc: 0.7892
#
# Epoch 00044: val_acc did not improve from 0.81289
# Epoch 45/100
# 389/389 [==============================] - 606s 2s/step - loss: 0.1367 - acc: 0.9568 - val_loss: 0.6828 - val_acc: 0.7907
#
# Epoch 00045: val_acc did not improve from 0.81289
# Epoch 46/100
# 156/389 [===========>..................] - ETA: 4:57 - loss: 0.1389 - acc: 0.9558

# %%
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.legend(['train', 'test'], loc='upper left')
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.legend(['train', 'test'], loc='lower left')
plt.title('Training and validation loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d1336c8d4b91> in <module>()
#       1 # Retrieve a list of accuracy results on training and test data
#       2 # sets for each training epoch
# ----> 3 acc = history.history['acc']
#       4 val_acc = history.history['val_acc']
#       5
#
# NameError: name 'history' is not defined
