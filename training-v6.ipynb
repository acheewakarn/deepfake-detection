# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
import zipfile
import time
import os
import cv2
import numpy as np
import json
import tensorflow as tf
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten, concatenate, LSTM, Lambda, TimeDistributed
from keras.models import Model, load_model, model_from_json
from keras.backend import expand_dims
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, CSVLogger
from VideoDataGenerator import VideoDataGenerator
import tensorflow as tf
from keras.layers import Reshape, Dense, Input, Conv2D, MaxPooling2D, Flatten, concatenate, LSTM, Lambda, TimeDistributed, Dropout, BatchNormalization
from keras.models import Model
from keras.backend import expand_dims
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def loadMetadata(file):
    jsonFile =  open(file)
    data = json.load(jsonFile)

    labels = {}
    testIDs = []
    validIDs = []
    # every fifth key is validID, the rest are testID
    
    for validID in data['valid'].keys():
        validIDs.append(validID)
        labels[validID] = {
          'label': data['valid'][validID]['label'],
          'audioPrediction': data['valid'][validID]['fakeAudioPrediction']
        }
        
    for testID in data['test'].keys():
        testIDs.append(testID)
        labels[testID] = {
          'label': data['test'][testID]['label'],
          'audioPrediction': data['test'][testID]['fakeAudioPrediction']
        }
        
    return (testIDs, validIDs, labels, len(testIDs), len(validIDs))

# %%
#    -- Image PreProcessing Model --

# Our input feature map is 150x150x3: 150x150 for the image pixels, and 3 for
# the three color channels: R, G, and B
vid_input = Input(shape=(90, 150, 150, 3))

# First convolution extracts 4 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
# Increase first set of filters from v2
model = TimeDistributed(Conv2D(5, (5,5), activation='relu'))(vid_input)
model = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(model)
model = TimeDistributed(BatchNormalization())(model)

# Second convolution extracts 5 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window

model = TimeDistributed(Conv2D(6, (5,5), activation='relu'))(model)
model = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(model)
model = TimeDistributed(BatchNormalization())(model)

# Third convolution extracts 10 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window

model = TimeDistributed(Conv2D(10, (5,5), activation='relu'))(model)
model = TimeDistributed(MaxPooling2D(pool_size=(2,2)))(model)
model = TimeDistributed(BatchNormalization())(model)


model = TimeDistributed(Flatten())(model)

#    -- Audio PreProcessing Model --
aud_input = Input(shape=(1,))

# Put through a layer with linear activation
aud_model = Dense(90, activation='linear')(aud_input)
aud_model = Reshape((90,1))(aud_model)

#     -- Concatenate Layers --
model = concatenate([model, aud_model])

model = TimeDistributed(Dense(1024, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)
model = TimeDistributed(Dense(516, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)
model = TimeDistributed(Dense(256, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)
model = TimeDistributed(Dense(127, activation='relu'))(model)
model = TimeDistributed(BatchNormalization())(model)
model = TimeDistributed(Dropout(0.4))(model)

model = LSTM(1)(model)

output = Dense(1, activation='sigmoid')(model)

model = Model(inputs=[vid_input, aud_input], outputs=output)

print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 90, 150, 150, 0
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 90, 146, 146, 380         input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 90, 73, 73, 5 0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 90, 73, 73, 5 20          time_distributed_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 90, 69, 69, 6 756         time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 90, 34, 34, 6 0           time_distributed_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 90, 34, 34, 6 24          time_distributed_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 90, 30, 30, 1 1510        time_distributed_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 90, 15, 15, 1 0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 90, 15, 15, 1 40          time_distributed_30[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 90)           180         input_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 90, 2250)     0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 90, 1)        0           dense_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 90, 2251)     0           time_distributed_32[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 90, 1024)     2306048     concatenate_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 90, 1024)     4096        time_distributed_33[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 90, 1024)     0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 90, 516)      528900      time_distributed_35[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 90, 516)      2064        time_distributed_36[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 90, 516)      0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 90, 256)      132352      time_distributed_38[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 90, 256)      1024        time_distributed_39[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 90, 256)      0           time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 90, 127)      32639       time_distributed_41[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 90, 127)      508         time_distributed_42[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 90, 127)      0           time_distributed_43[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 1)            516         time_distributed_44[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            2           lstm_2[0][0]
# ==================================================================================================
# Total params: 3,011,059
# Trainable params: 3,007,171
# Non-trainable params: 3,888
# __________________________________________________________________________________________________
# None

# %%
modelDirectory = '/home/jbschmid/models/v6'
dataDirectory = '/home/jbschmid/merged_data'

modelPath = os.path.join(modelDirectory, 'model.h5')
loadWeightsPath = os.path.join(modelDirectory, 'weights.h5')
saveWeightsPath = os.path.join(modelDirectory, 'weights.h5')
historyPath = os.path.join(modelDirectory, 'history.csv')
metadataPath =  './processed-metadata.json'

# load model
#model.save(modelPath)

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr = 0.001),
              metrics = ['acc'])

# Load previous training weights
#model.load_weights(loadWeightsPath)
checkpoint = ModelCheckpoint(filepath=saveWeightsPath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

csvLogger = CSVLogger(historyPath, append=True, separator=',')

(testIDs, validIDs, labels, numTestIDs, numValidIDs) = loadMetadata(metadataPath)

epochs = 50
batchSize = 20
testStepsPerEpoch = int(numTestIDs / batchSize)
validStepsPerEpoch = int(numValidIDs / batchSize)

testGen = VideoDataGenerator(testIDs, labels, dataDirectory, 
                             batchSize=batchSize, videoDim=(150,150,3))
validGen = VideoDataGenerator(validIDs, labels, dataDirectory, 
                              batchSize=batchSize, videoDim=(150,150,3))


# Train model
history = model.fit_generator(
      generator=testGen,
      steps_per_epoch=testStepsPerEpoch,  
      epochs=epochs,
      validation_data=validGen,
      validation_steps=validStepsPerEpoch,
      workers=8,
      callbacks=[checkpoint, csvLogger]
      )
# Out:
# Epoch 1/50
# 389/389 [==============================] - 629s 2s/step - loss: 0.6769 - acc: 0.5554 - val_loss: 0.6767 - val_acc: 0.5552
#
# Epoch 00001: val_acc improved from -inf to 0.55515, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 2/50
# 389/389 [==============================] - 616s 2s/step - loss: 0.6546 - acc: 0.5906 - val_loss: 0.6561 - val_acc: 0.5820
#
# Epoch 00002: val_acc improved from 0.55515 to 0.58196, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 3/50
# 389/389 [==============================] - 617s 2s/step - loss: 0.6273 - acc: 0.6537 - val_loss: 0.6183 - val_acc: 0.6753
#
# Epoch 00003: val_acc improved from 0.58196 to 0.67526, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 4/50
# 389/389 [==============================] - 615s 2s/step - loss: 0.6019 - acc: 0.6919 - val_loss: 0.7108 - val_acc: 0.6320
#
# Epoch 00004: val_acc did not improve from 0.67526
# Epoch 5/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.5905 - acc: 0.7054 - val_loss: 0.5885 - val_acc: 0.7052
#
# Epoch 00005: val_acc improved from 0.67526 to 0.70515, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 6/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.5683 - acc: 0.7320 - val_loss: 0.5955 - val_acc: 0.6959
#
# Epoch 00006: val_acc did not improve from 0.70515
# Epoch 7/50
# 389/389 [==============================] - 616s 2s/step - loss: 0.5574 - acc: 0.7356 - val_loss: 0.6417 - val_acc: 0.6180
#
# Epoch 00007: val_acc did not improve from 0.70515
# Epoch 8/50
# 389/389 [==============================] - 615s 2s/step - loss: 0.5400 - acc: 0.7495 - val_loss: 0.5478 - val_acc: 0.7387
#
# Epoch 00008: val_acc improved from 0.70515 to 0.73866, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 9/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.5137 - acc: 0.7638 - val_loss: 0.4964 - val_acc: 0.7742
#
# Epoch 00009: val_acc improved from 0.73866 to 0.77423, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 10/50
# 389/389 [==============================] - 615s 2s/step - loss: 0.4856 - acc: 0.7802 - val_loss: 0.5756 - val_acc: 0.7088
#
# Epoch 00010: val_acc did not improve from 0.77423
# Epoch 11/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.4615 - acc: 0.7936 - val_loss: 0.4906 - val_acc: 0.7624
#
# Epoch 00011: val_acc did not improve from 0.77423
# Epoch 12/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.4432 - acc: 0.8082 - val_loss: 0.4651 - val_acc: 0.7789
#
# Epoch 00012: val_acc improved from 0.77423 to 0.77887, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 13/50
# 389/389 [==============================] - 613s 2s/step - loss: 0.4114 - acc: 0.8253 - val_loss: 0.4591 - val_acc: 0.7990
#
# Epoch 00013: val_acc improved from 0.77887 to 0.79897, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 14/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.3860 - acc: 0.8323 - val_loss: 0.4770 - val_acc: 0.7851
#
# Epoch 00014: val_acc did not improve from 0.79897
# Epoch 15/50
# 389/389 [==============================] - 613s 2s/step - loss: 0.3675 - acc: 0.8465 - val_loss: 0.4745 - val_acc: 0.7974
#
# Epoch 00015: val_acc did not improve from 0.79897
# Epoch 16/50
# 389/389 [==============================] - 613s 2s/step - loss: 0.3534 - acc: 0.8491 - val_loss: 0.4670 - val_acc: 0.8046
#
# Epoch 00016: val_acc improved from 0.79897 to 0.80464, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 17/50
# 389/389 [==============================] - 612s 2s/step - loss: 0.3339 - acc: 0.8517 - val_loss: 0.4974 - val_acc: 0.7907
#
# Epoch 00017: val_acc did not improve from 0.80464
# Epoch 18/50
# 389/389 [==============================] - 612s 2s/step - loss: 0.3136 - acc: 0.8670 - val_loss: 0.8834 - val_acc: 0.5680
#
# Epoch 00018: val_acc did not improve from 0.80464
# Epoch 19/50
# 389/389 [==============================] - 613s 2s/step - loss: 0.3000 - acc: 0.8725 - val_loss: 0.4791 - val_acc: 0.7871
#
# Epoch 00019: val_acc did not improve from 0.80464
# Epoch 20/50
# 389/389 [==============================] - 615s 2s/step - loss: 0.2997 - acc: 0.8753 - val_loss: 0.5520 - val_acc: 0.7490
#
# Epoch 00020: val_acc did not improve from 0.80464
# Epoch 21/50
# 389/389 [==============================] - 616s 2s/step - loss: 0.2871 - acc: 0.8803 - val_loss: 0.5408 - val_acc: 0.7881
#
# Epoch 00021: val_acc did not improve from 0.80464
# Epoch 22/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.2654 - acc: 0.8918 - val_loss: 0.4484 - val_acc: 0.8155
#
# Epoch 00022: val_acc improved from 0.80464 to 0.81546, saving model to /home/jbschmid/models/v6/weights.h5
# Epoch 23/50
# 389/389 [==============================] - 614s 2s/step - loss: 0.2500 - acc: 0.9010 - val_loss: 0.4897 - val_acc: 0.8103
#
# Epoch 00023: val_acc did not improve from 0.81546
# Epoch 24/50
# 389/389 [==============================] - 612s 2s/step - loss: 0.2513 - acc: 0.8960 - val_loss: 0.5194 - val_acc: 0.8010
#
# Epoch 00024: val_acc did not improve from 0.81546
# Epoch 25/50
# 389/389 [==============================] - 612s 2s/step - loss: 0.2393 - acc: 0.9057 - val_loss: 0.5280 - val_acc: 0.7845
#
# Epoch 00025: val_acc did not improve from 0.81546
# Epoch 26/50
# 389/389 [==============================] - 611s 2s/step - loss: 0.2298 - acc: 0.9136 - val_loss: 0.4892 - val_acc: 0.8046
#
# Epoch 00026: val_acc did not improve from 0.81546
# Epoch 27/50
# 389/389 [==============================] - 609s 2s/step - loss: 0.2269 - acc: 0.9140 - val_loss: 0.4830 - val_acc: 0.8046
#
# Epoch 00027: val_acc did not improve from 0.81546
# Epoch 28/50
# 389/389 [==============================] - 609s 2s/step - loss: 0.2070 - acc: 0.9225 - val_loss: 0.5425 - val_acc: 0.7959
#
# Epoch 00028: val_acc did not improve from 0.81546
# Epoch 29/50
#   8/389 [..............................] - ETA: 8:57 - loss: 0.1846 - acc: 0.9375

# %%
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.legend(['train', 'test'], loc='upper left')
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.legend(['train', 'test'], loc='lower left')
plt.title('Training and validation loss')
